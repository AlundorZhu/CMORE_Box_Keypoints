# %%
from ultralytics import YOLO

MODEL_TYPE = "yolo11n-pose"
model = YOLO(MODEL_TYPE)

result = model.train(
    project="runs/pose",
    name=PROJECT_NAME,
    data=DATA_YAML,
    epochs=15,
    batch=32,
    save_period=5,
    fliplr=0.0,
)
